# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data

# %%
path = r'C:\Users\ariel\OneDrive\Desktop\School work\08-2020 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\ariel\\OneDrive\\Desktop\\School work\\08-2020 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %% [markdown]
# ## Creating a Subset of the Data

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# ...

# %% [markdown]
# ## Grouping Data with Pandas

# %%
df.groupby('product_name')

# %% [markdown]
# ## Aggregating Data with agg()

# %%
#Grouping data into groups based on department ID and aggregating each group to obtain the mean values for the order number column
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
#Calculating despriptive statistics in the order number column
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ## Aggregating Data with transform() On Full Dataset (Step 4 in task)

# %%
#Using the transform function to find loyal customers
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
#Sorting the data set by the beginning of the user ID column
ords_prods_merge_sort = ords_prods_merge.sort_values(by = 'user_id')

# %%
ords_prods_merge_sort
# Out:
#           product_id                                       product_name  \
# 6002731        10326                                Organic Fuji Apples
# 92374            196                                               Soda
# 92373            196                                               Soda
# 92371            196                                               Soda
# 92370            196                                               Soda
# ...              ...                                                ...
# 21518543       33129                                     Classic Hummus
# 12350504       20842                              Total 0% Greek Yogurt
# 26342158       40992                                   Chopped Tomatoes
# 26025010       40534              In Rich Tomato Sauce Vegetarian Beans
# 14855822       23892  Original High Efficiency Liquid Laundry Detergent
#
#           aisle_id  department_id  prices  order_id  user_id eval_set  \
# ...

# %%
ords_prods_merge_sort.head(100)
# Out:
#           product_id                                    product_name  \
# 6002731        10326                             Organic Fuji Apples
# 92374            196                                            Soda
# 92373            196                                            Soda
# 92371            196                                            Soda
# 92370            196                                            Soda
# ...              ...                                             ...
# 8696291        14553                            Oats & Honey Granola
# 30394388       47144  Unsweetened Original Almond Breeze Almond Milk
# 15430750       24852                                          Banana
# 30454263       47209                            Organic Hass Avocado
# 21299894       32792                  Chipotle Beef & Pork Realstick
#
#           aisle_id  department_id  prices  order_id  user_id eval_set  \
# ...

# %%
#Removing the limit to the amount of rows shown on the dataset
pd.options.display.max_rows = None

# %% [markdown]
# ## Deriving Columns with loc() From exercise (Also Step 4 in task)

# %%
##Creating the flag that assigns a loyalty label to a user ID
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.head(5)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  ...  \
# 0   3139998      138    prior            28                   6  ...
# 1   1977647      138    prior            30                   6  ...
# 2    389851      709    prior             2                   0  ...
# 3    652770      764    prior             1                   3  ...
# 4   1813452      764    prior             3                   4  ...
#
#    days_since_last_order  add_to_cart_order  reordered  _merge  \
# ...

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %% [markdown]
# ## Finding the aggregated mean of the order number coluimn grouped by department ID for the entire dataframe

# %%
#2
#Finding the aggregated mean of the order number coluimn grouped by department ID for the entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #3.
# The means in the subset of the data are slightly different from the means in the full dataset. Some means are higher and lower, but they are all sligtly different.

# %% [markdown]
# ## Looking for difference in spending habits by product prices between the 3 types of customers. #5.

# %%
# Use groupby and agg() to determine basic statisitcs of spending habits by loyalty group
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The loyal customers pay the least on average for products. New customers spend about $3.00 more on average on products.

# %% [markdown]
# ## Creating a spending flag for customers #6.

# %%
# Use transform() to determine the mean price of products purchased by each user
ords_prods_merge['mean_product_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
ords_prods_merge[['user_id', 'mean_product_price']].head(20)
# Out:
#     user_id  mean_product_price
# 0       138            6.935811
# 1       138            6.935811
# 2       709            7.930208
# 3       764            4.972414
# 4       764            4.972414
# 5       777            6.935398
# 6       825            5.957576
# 7       910            6.680000
# 8      1052            7.162500
# 9      1052            7.162500
# 10     1379            5.813636
# 11     1480            5.081633
# 12     1480            5.081633
# 13     1480            5.081633
# 14     1494            6.803797
# 15     1494            6.803797
# 16     1494            6.803797
# 17     1540            6.607122
# 18     1540            6.607122
# 19     1540            6.607122

# %%
# Create spending_flag column using loc() function
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#Check frequency of new spending_flag column
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
# View relevant columns of updated data frame
ords_prods_merge[['user_id', 'mean_product_price', 'spending_flag']].head(20)
# Out:
#     user_id  mean_product_price spending_flag
# 0       138            6.935811   Low spender
# 1       138            6.935811   Low spender
# 2       709            7.930208   Low spender
# 3       764            4.972414   Low spender
# 4       764            4.972414   Low spender
# 5       777            6.935398   Low spender
# 6       825            5.957576   Low spender
# 7       910            6.680000   Low spender
# 8      1052            7.162500   Low spender
# 9      1052            7.162500   Low spender
# 10     1379            5.813636   Low spender
# 11     1480            5.081633   Low spender
# 12     1480            5.081633   Low spender
# 13     1480            5.081633   Low spender
# 14     1494            6.803797   Low spender
# 15     1494            6.803797   Low spender
# 16     1494            6.803797   Low spender
# 17     1540            6.607122   Low spender
# 18     1540            6.607122   Low spender
# ...

# %% [markdown]
# ## Determining frequent vs. non-frequent customers based on frequency and regularity of a user's ordering behavior #7.

# %%
##Use groupby and transform to determine median number of days between orders for each user
ords_prods_merge['median_days_between_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform('median')

# %%
ords_prods_merge[['user_id', 'days_since_last_order', 'median_days_between_orders']].head(20)
# Out:
#     user_id  days_since_last_order  median_days_between_orders
# 0       138                   3.00                        8.00
# 1       138                  20.00                        8.00
# 2       709                   6.00                        8.00
# 3       764                  11.11                       11.11
# 4       764                   9.00                       11.11
# 5       777                  26.00                       11.00
# 6       825                  30.00                       19.00
# 7       910                  30.00                        6.00
# 8      1052                  19.00                       10.00
# 9      1052                  15.00                       10.00
# 10     1379                  11.11                       20.00
# 11     1480                   7.00                        7.00
# 12     1480                   7.00                        7.00
# 13     1480                  12.00                        7.00
# ...

# %%
# Create order frequency flag using loc function
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_between_orders'] <= 20) & (ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
# Check value counts of new order_frequency column
ords_prods_merge['order_frequency'].value_counts(dropna = False)
# Out:
# order_frequency
# Frequent customer        20535136
# Regular customer          9168905
# Non-frequent customer     2700818
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'days_since_last_order', 'median_days_between_orders', 'order_frequency']].head(25)
# Out:
#     user_id  days_since_last_order  median_days_between_orders  \
# 0       138                   3.00                        8.00
# 1       138                  20.00                        8.00
# 2       709                   6.00                        8.00
# 3       764                  11.11                       11.11
# 4       764                   9.00                       11.11
# 5       777                  26.00                       11.00
# 6       825                  30.00                       19.00
# 7       910                  30.00                        6.00
# 8      1052                  19.00                       10.00
# 9      1052                  15.00                       10.00
# 10     1379                  11.11                       20.00
# 11     1480                   7.00                        7.00
# 12     1480                   7.00                        7.00
# 13     1480                  12.00                        7.00
# ...

# %% [markdown]
# ## Cleaning up outliers in data Task 4.9

# %%
#Investigating outliers (any price beyond $100)
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           product_id                      product_name  aisle_id  \
# 13100147       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100148       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100149       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100150       21553  Lowfat 2% Milkfat Cottage Cheese       108
# 13100151       21553  Lowfat 2% Milkfat Cottage Cheese       108
# ...              ...                               ...       ...
# 21786876       33664             2 % Reduced Fat  Milk        84
# 21786877       33664             2 % Reduced Fat  Milk        84
# 21786878       33664             2 % Reduced Fat  Milk        84
# 21786879       33664             2 % Reduced Fat  Milk        84
# 21786880       33664             2 % Reduced Fat  Milk        84
#
#           department_id   prices  order_id  user_id eval_set  order_number  \
# 13100147             16  14900.0    912404       17    prior            12
# ...

# %%
#Marking outliers as missing values
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ## Exporting Data

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_grouped.pkl'))
